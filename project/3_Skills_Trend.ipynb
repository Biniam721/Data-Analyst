# %% [markdown]
# ### How are in-demands skills trending for data analysts?
#
# #### Methodolgy
#
# 1. Aggregate skill counts monthly
# 2. Re-analyzed based on percentage of total jobs
# 3. Plot the monthly skill demand

# %%
import ast
import seaborn as sns 
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset
from adjustText import adjust_text

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_DA_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()

# %%
df_DA_US['job_posted_month_no'] = df_DA_US['job_posted_date'].dt.month

# %%
df_DA_US_explode = df_DA_US.explode('job_skills')

# %%
df_explode_pivots = df_DA_US_explode.pivot_table(index='job_posted_month_no', columns='job_skills', aggfunc='size', fill_value=0)
df_explode_pivots.loc['Total'] = df_explode_pivots.sum()
df_explode_pivots = df_explode_pivots[df_explode_pivots.loc['Total'].sort_values(ascending=False).index]
df_explode_pivots = df_explode_pivots.drop('Total')

# %%
G_total = df_DA_US.groupby('job_posted_month_no').size()
df_DA_US_percent = df_explode_pivots.div(G_total/100, axis=0)
df_DA_US_percent
# Out:
# job_skills                 sql      excel    tableau     python        sas  \
# job_posted_month_no
# 1                    54.167648  42.288674  29.291264  26.536379  21.568166
# 2                    51.730895  42.243632  27.367734  26.420640  19.790986
# 3                    51.881634  42.795111  29.012544  27.066581  19.909939
# 4                    53.231939  42.139197  29.575136  27.756654  21.524219
# 5                    51.692369  42.419387  28.680152  27.017825  19.467254
# 6                    50.360725  41.914482  28.646841  28.312511  17.314799
# 7                    50.163430  40.722938  29.475101  27.648529  19.150163
# 8                    51.462165  41.166717  29.409105  30.524570  19.234248
# 9                    49.471869  38.823022  29.165768  26.492779  18.452253
# 10                   48.833238  36.463669  27.110605  26.048188  18.212863
# 11                   45.332156  33.833591  25.336570  23.151622  17.479585
# ...

# %%
df_DA_US_percent = df_DA_US_percent.reset_index()
df_DA_US_percent['job_posted_month'] = df_DA_US_percent['job_posted_month_no'].apply(lambda x: pd.to_datetime(x, format='%m').strftime('%b'))
df_DA_US_percent = df_DA_US_percent.set_index('job_posted_month')
df_DA_US_percent = df_DA_US_percent.drop(columns='job_posted_month_no')
df_DA_US_percent
# Out:
# job_skills              sql      excel    tableau     python        sas  \
# job_posted_month
# Jan               54.167648  42.288674  29.291264  26.536379  21.568166
# Feb               51.730895  42.243632  27.367734  26.420640  19.790986
# Mar               51.881634  42.795111  29.012544  27.066581  19.909939
# Apr               53.231939  42.139197  29.575136  27.756654  21.524219
# May               51.692369  42.419387  28.680152  27.017825  19.467254
# Jun               50.360725  41.914482  28.646841  28.312511  17.314799
# Jul               50.163430  40.722938  29.475101  27.648529  19.150163
# Aug               51.462165  41.166717  29.409105  30.524570  19.234248
# Sep               49.471869  38.823022  29.165768  26.492779  18.452253
# Oct               48.833238  36.463669  27.110605  26.048188  18.212863
# Nov               45.332156  33.833591  25.336570  23.151622  17.479585
# Dec               46.443830  38.326213  27.142498  27.041970  19.602915
#
# ...

# %%
df_plot = df_DA_US_percent.iloc[:, :5]

sns.lineplot(data=df_plot, dashes=False, palette='tab10')
sns.set_theme(style='ticks')
sns.despine()

plt.title('Trending Top Skills for Data Analyst in Germany')
plt.ylabel('Likelihood in Job Posting')
plt.xlabel('2023')
plt.legend().remove()

import numpy as np
from matplotlib.ticker import PercentFormatter
ax = plt.gca()
ax.yaxis.set_major_formatter(PercentFormatter(decimals=0))

for i in range(5):
    plt.text(11.2, df_plot.iloc[-1, i], df_plot.columns[i])

plt.yticks(np.linspace(20, 60, 5))

plt.tight_layout()
plt.show()

# %%
df_DA_G_percent.iloc[:, :5]
# Out:
# job_skills              sql     python    tableau      excel   power bi
# job_posted_month
# Jan               41.442953  35.906040  23.322148  17.617450  15.100671
# Feb               40.472175  31.871838  22.765599  23.102867  20.404722
# Mar               43.642612  30.240550  18.041237  18.556701  19.415808
# Apr               47.577093  34.361233  22.026432  18.502203  21.145374
# May               43.488372  34.883721  22.093023  20.930233  19.767442
# Jun               41.935484  33.333333  18.458781  16.666667  18.458781
# Jul               45.321101  38.532110  18.899083  17.431193  18.165138
# Aug               44.376278  31.288344  19.836401  16.564417  19.222904
# Sep               37.804878  29.878049  17.225610  14.786585  16.920732
# Oct               38.633377  29.960578  15.505913  19.710907  18.528252
# Nov               39.357430  29.718876  18.206158  19.009371  17.001339
# Dec               37.361111  31.805556  16.944444  20.416667  17.361111
